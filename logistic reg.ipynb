# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

dataset = pd.read_csv(r"C:\Users\Ahsan\Downloads\social_network_ads_data.csv")
dataset.drop(columns="EstimatedSalary" ,inplace=True)
print(dataset.head(3))
# Out:
#    Age  Purchased
# 0   22          0
# 1   35          1
# 2   26          0

# %%
plt.figure(figsize=(4, 3))
sns.scatterplot(x="Age", y="Purchased", data=dataset)
plt.show()

# %%
x = dataset[["Age"]]
y = dataset['Purchased']

# %%
from sklearn.model_selection import train_test_split

x_train_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=48)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(x_train_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 100.0

# %%
lr.predict([[30]])
# Out:
# C:\Users\Ahsan\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
plt.figure(figsize=(6, 5))
sns.scatterplot(x ="Age", y="Purchased", data=dataset)
sns.lineplot(x = "Age" , y = lr.predict(x),data=dataset , color = 'red')
plt.show()
